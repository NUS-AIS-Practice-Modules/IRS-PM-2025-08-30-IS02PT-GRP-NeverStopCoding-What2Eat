# %%
import os, getpass, requests, time
from typing import Dict, Any, List

# 安全地注入 API Key（建议在 GCP 控制台为 Places API 启用后再粘贴）
if "GOOGLE_MAPS_API_KEY" not in os.environ:
    os.environ["GOOGLE_MAPS_API_KEY"] = getpass.getpass("请输入你的 Google Maps API Key（不可见）: ")

API_KEY = os.environ["GOOGLE_MAPS_API_KEY"]
BASE = "https://places.googleapis.com/v1"

def call_places(method: str, path: str, field_mask: str,
                json_body: Dict[str, Any] | None = None,
                params: Dict[str, Any] | None = None) -> Dict[str, Any]:
    """通用调用器：封装 X-Goog-FieldMask / X-Goog-Api-Key 头"""
    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": field_mask,   # 必须！否则报错
    }
    url = f"{BASE}{path}"
    resp = requests.request(method, url, headers=headers, json=json_body, params=params, timeout=30)
    resp.raise_for_status()
    return resp.json()
# Out:
# 请输入你的 Google Maps API Key（不可见）: ··········

# %% [markdown]
# #1.Nearby Search（指定点与半径找“餐厅”）
#
# • 仅支持 POST，请求体里写范围（圆形中心 + 半径）。
#
# • 示例字段掩码只拿到 ID、地理位置、地址、评分、价格等用于做餐厅画像的关键字段

# %%
# 你可以换成自己的坐标与半径；这里示例：新加坡 Orchard Road 附近
center_lat, center_lng = 1.3049, 103.8318  # Orchard 附近
radius_m = 1500.0

# 为 Nearby 准备一个最小够用的字段掩码（不要包含 nextPageToken —— 官方页未明确 Nearby 的翻页字段）
SEARCH_MASK_NEARBY = ",".join([
    "places.id",
    "places.displayName",
    "places.location",
    "places.formattedAddress",
    "places.primaryType",
    "places.types",
    "places.rating",
    "places.userRatingCount",
    "places.priceLevel",
    "places.googleMapsUri"
])

nearby_body = {
    "includedTypes": ["restaurant"],  # 也可用 includedPrimaryTypes
    "maxResultCount": 20,             # Nearby 单页最多 20
    "rankPreference": "POPULARITY",   # 或 "DISTANCE"
    "locationRestriction": {
        "circle": {
            "center": {"latitude": center_lat, "longitude": center_lng},
            "radius": radius_m
        }
    }
}

nearby = call_places("POST", "/places:searchNearby", SEARCH_MASK_NEARBY, json_body=nearby_body)
len(nearby.get("places", [])), nearby.get("places", [])[:2]  # 看下总数与前两个示例
# Out:
# (20,
#  [{'id': 'ChIJe4wL_OsZ2jERySoDk6jlhNQ',
#    'types': ['food_court',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'formattedAddress': '500 Clemenceau Ave N, Singapore 229495',
#    'location': {'latitude': 1.3119888, 'longitude': 103.8395742},
#    'rating': 4.2,
#    'googleMapsUri': 'https://maps.google.com/?cid=15313617145150253769&g_mp=Cilnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaE5lYXJieRAAGAQgAA',
#    'userRatingCount': 14394,
#    'displayName': {'text': 'Newton Food Centre', 'languageCode': 'en'},
#    'primaryType': 'food_court'},
#   {'id': 'ChIJdY7JN4oZ2jERVg6-qPEGJ3U',
#    'types': ['hotel',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'formattedAddress': '1A Cuscaden Rd, Singapore 249716',
#    'location': {'latitude': 1.3043259999999999, 'longitude': 103.8239282},
#    'rating': 4.3,
#    'googleMapsUri': 'https://maps.google.com/?cid=8441723661517196886&g_mp=Cilnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaE5lYXJieRAAGAQgAA',
#    'userRatingCount': 5873,
#    'displayName': {'text': 'JEN Singapore Tanglin by Shangri-La',
#     'languageCode': 'en'},
#    'primaryType': 'hotel'}])

# %% [markdown]
# #2.Text Search（关键词 + 区域偏置）
#
# • POST 到 places:searchText，textQuery 可以写 “sushi near orchard road singapore”。
#
# • pageSize 控制每页数量；响应里若返回 nextPageToken，用它继续翻页（放在请求体的 pageToken 字段）。

# %%
# Text Search 字段掩码：与 Nearby 类似，但加入 nextPageToken 以便分页
SEARCH_MASK_TEXT = ",".join([
    "places.id",
    "places.displayName",
    "places.location",
    "places.formattedAddress",
    "places.primaryType",
    "places.types",
    "places.rating",
    "places.userRatingCount",
    "places.priceLevel",
    "places.googleMapsUri",
    "nextPageToken"
])

text_body = {
    "textQuery": "sushi near orchard road singapore",
    # 用 locationBias 把结果“往某区域靠”
    "locationBias": {
        "circle": {
            "center": {"latitude": center_lat, "longitude": center_lng},
            "radius": 1200.0
        }
    },
    "pageSize": 10
}

page1 = call_places("POST", "/places:searchText", SEARCH_MASK_TEXT, json_body=text_body)
print("第一页条数:", len(page1.get("places", [])))
print("是否可翻页:", "nextPageToken" in page1)

# 若可翻页，继续拿第二页
page2 = {}
if "nextPageToken" in page1:
    text_body2 = {**text_body, "pageToken": page1["nextPageToken"]}
    # 按官方示例，翻页前稍等一小会儿更稳妥
    time.sleep(1.2)
    page2 = call_places("POST", "/places:searchText", SEARCH_MASK_TEXT, json_body=text_body2)
    print("第二页条数:", len(page2.get("places", [])))
# Out:
# 第一页条数: 10
# 是否可翻页: True
# 第二页条数: 10

# %% [markdown]
# #3.Place Details（对单个餐厅补充细节）
#
# • GET 到 /v1/places/{PLACE_ID}，同样必须带 FieldMask。
# • 支持补充电话、网站、营业时间、评分/价位等（不同字段触发不同 SKU）

# %%
# 拿 Nearby 或 Text Search 的第一个结果做示例
any_place_id = (nearby.get("places") or page1.get("places") or page2.get("places"))[0]["id"]

DETAILS_MASK = ",".join([
    # 注意：Place Details 的字段掩码是 Place 对象顶层，不再以 "places." 起头！
    "id",
    "displayName",
    "location",
    "formattedAddress",
    "primaryType",
    "types",
    "rating",
    "userRatingCount",
    "priceLevel",
    "websiteUri",
    "nationalPhoneNumber",
    "currentOpeningHours",
    "googleMapsUri",
])

details = call_places("GET", f"/places/{any_place_id}", DETAILS_MASK)
details
# Out:
# {'id': 'ChIJe4wL_OsZ2jERySoDk6jlhNQ',
#  'types': ['food_court',
#   'restaurant',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  'formattedAddress': '500 Clemenceau Ave N, Singapore 229495',
#  'location': {'latitude': 1.3119888, 'longitude': 103.8395742},
#  'rating': 4.2,
#  'googleMapsUri': 'https://maps.google.com/?cid=15313617145150253769&g_mp=CiVnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLkdldFBsYWNlEAAYBCAA',
#  'userRatingCount': 14394,
#  'displayName': {'text': 'Newton Food Centre', 'languageCode': 'en'},
#  'currentOpeningHours': {'openNow': True,
#   'periods': [{'open': {'day': 2,
#      'hour': 0,
#      'minute': 0,
#      'truncated': True,
#      'date': {'year': 2025, 'month': 9, 'day': 9}},
#     'close': {'day': 1,
#      'hour': 23,
#      'minute': 59,
#      'truncated': True,
#      'date': {'year': 2025, 'month': 9, 'day': 15}}}],
#   'weekdayDescriptions': ['Monday: Open 24 hours',
#    'Tuesday: Open 24 hours',
#    'Wednesday: Open 24 hours',
#    'Thursday: Open 24 hours',
#    'Friday: Open 24 hours',
#    'Saturday: Open 24 hours',
#    'Sunday: Open 24 hours']},
#  'primaryType': 'food_court'}

# %% [markdown]
# #4.把结果整理成“餐厅画像”结构

# %%
import pandas as pd

def to_profile(p: Dict[str, Any]) -> Dict[str, Any]:
    lat = p.get("location", {}).get("latLng", {}).get("latitude")
    lng = p.get("location", {}).get("latLng", {}).get("longitude")
    return {
        "id": p.get("id"),
        "name": p.get("displayName", {}).get("text"),
        "lat": lat, "lng": lng,
        "address": p.get("formattedAddress"),
        "googleMapsUrl": p.get("googleMapsUri"),
        "rating": p.get("rating"),
        "ratingCount": p.get("userRatingCount"),
        "priceLevel": p.get("priceLevel"),
        "primaryType": p.get("primaryType"),
        "types": ",".join(p.get("types", []))
    }

# 合并 Nearby + Text Search 的前若干结果，做个 DataFrame 方便查看/后处理
merged_places: List[Dict[str, Any]] = []
for blk in [nearby.get("places", []), page1.get("places", []), page2.get("places", [])]:
    for p in blk:
        merged_places.append(to_profile(p))

df = pd.DataFrame(merged_places).drop_duplicates(subset=["id"]).reset_index(drop=True)
df
# Out:
#                              id  \
# 0   ChIJe4wL_OsZ2jERySoDk6jlhNQ
# 1   ChIJdY7JN4oZ2jERVg6-qPEGJ3U
# 2   ChIJRe0Wq5cZ2jER5qoN9Q0znq8
# 3   ChIJS2f6Z40Z2jERLavQ4p6-R5s
# 4   ChIJq51Ft5YZ2jERd4ctVijFKeA
# 5   ChIJ_c6vFoMZ2jERBWATXfBQ7Aw
# 6   ChIJn7jj_5kZ2jERdhZzwXgi41Q
# 7   ChIJuTpnZVQZ2jEReDI4VP2u_w0
# 8   ChIJpfgvhowZ2jERbVbSD5w0-FY
# 9   ChIJDfcsE5EZ2jERrC6v6Okmdhc
# 10  ChIJ_anjs8wZ2jERX9UwtpK1JBQ
# 11  ChIJHXQYQ4QZ2jERORHe3xZyKRw
# 12  ChIJ61p5UZcZ2jERq2f3Wv25g-s
# 13  ChIJFVQEY2wZ2jERW2UyQdBP-gA
# 14  ChIJLdePZpAZ2jERnKQLaKbaVd4
# 15  ChIJSZujEpEZ2jERc0ez6ins24Y
# 16  ChIJuUC9Q4QZ2jERYooNz9ienBc
# 17  ChIJjQnjJ5cZ2jEREVwl4u3Lqds
# 18  ChIJ_1XUDOkZ2jER1ER-ny61Gc0
# 19  ChIJx_0Zje0Z2jER65Dro1YNoRw
# 20  ChIJRxO6WecZ2jER4klBDj9P1VY
# 21  ChIJ67u09pEZ2jERH1A0Y3WPq9M
# 22  ChIJhw9kfo0Z2jERQvBMA2bcwP8
# 23  ChIJvXooINwZ2jERn_rxsHoPs2I
# 24  ChIJW1RyMIIZ2jERTZxigpurlWY
# 25  ChIJ2f5AjkUZ2jERPkUVvmR-1r0
# 26  ChIJ8bnz9kcZ2jERVSyGXb1tmlA
# 27  ChIJ82KCjowZ2jER37FvW5wmONU
# 28  ChIJ09outpYZ2jERpJkALHa70vg
# 29  ChIJl_sOMpIZ2jERa4tZiOdKqvc
# 30  ChIJa3WCg1UZ2jERYOQO5qImyOw
# 31  ChIJbZFLfwAZ2jER7yIPFuEnjNM
# 32  ChIJmSi_YfMZ2jERGaDQFMy5WBo
# 33  ChIJz7GndUoZ2jER-GTootKzruQ
# 34  ChIJp-uNqpIZ2jERUXTpQwlsf4E
# 35  ChIJfb9EWWAZ2jERlr9BSoIMHsU
# 36  ChIJ3y7ASO0Z2jERg_TbzCflOgQ
# 37  ChIJl_sOMpIZ2jERS1oVkXQTBS8
# 38  ChIJ44Dq0BgZ2jERXhg_DvoY7Do
#
#                                                name   lat   lng  \
# 0                                Newton Food Centre  None  None
# 1               JEN Singapore Tanglin by Shangri-La  None  None
# 2                          Concorde Hotel Singapore  None  None
# 3                   Royal Plaza on Scotts Singapore  None  None
# 4     Song Fa Bak Kut Teh The Centrepoint 松發肉骨茶 先得坊  None  None
# 5                        Zion Riverside Food Centre  None  None
# 6                          Da Shi Jia Big Prawn Mee  None  None
# 7                              MERCI MARCEL ORCHARD  None  None
# 8                                    Hard Rock Cafe  None  None
# 9                                        Chatterbox  None  None
# 10              Happy Lamb Hot Pot 快乐小羊火锅 - Orchard  None  None
# 11                     Boon Tong Kee @ River Valley  None  None
# 12                                Killiney Kopitiam  None  None
# 13                                      Shake Shack  None  None
# 14                      JUMBO Seafood - ION Orchard  None  None
# 15                      Wild Honey Mandarin Gallery  None  None
# 16                               Zamas River Valley  None  None
# 17                     Tanuki Raw @ Orchard Central  None  None
# 18             Chui Huay Lim Teochew Cuisine 醉花林品潮轩  None  None
# 19                          Cédric Grolet Singapore  None  None
# 20                         千両 sen-ryo (ION Orchard)  None  None
# 21                          The Sushi Bar (Orchard)  None  None
# 22                       Ginza Sushi Ichi Singapore  None  None
# 23                         Genki Sushi 313@somerset  None  None
# 24           Katachi Sushi Bar-Sushi&Japanese wine-  None  None
# 25                                Tsukiji Sushi TEN  None  None
# 26                            Sushiro Taste Orchard  None  None
# 27                         Hana Japanese Restaurant  None  None
# 28                                           Misato  None  None
# 29                                        SUSHI TEI  None  None
# 30                    Sushi Ayumu by Masa Ishibashi  None  None
# 31                                         Akami SG  None  None
# 32                           Sushi Masa by Ki-setsu  None  None
# 33                                     Kyojo Dining  None  None
# 34                                           Hazuki  None  None
# 35  Gyu San Japanese Restaurant & Izakaya (Orchard)  None  None
# 36                                 Tatsuya@Goodwood  None  None
# 37                       Akashi Japanese Restaurant  None  None
# 38     寿司 九 | Sushi Kyuu By Shunsui (Orchard Plaza)  None  None
#
#                                               address  \
# 0              500 Clemenceau Ave N, Singapore 229495
# 1                    1A Cuscaden Rd, Singapore 249716
# 2                    100 Orchard Rd, Singapore 238840
# 3                      25 Scotts Rd, Singapore 228220
# 4         176 Orchard Rd, #02-29/30, Singapore 238843
# 5                        70 Zion Rd, Singapore 247792
# 6                    89 Killiney Rd, Singapore 239534
# 7   390 Orchard Road, 01-03 Palais Renaissance, 39...
# 8   50 Cuscaden Rd, #02-01 Hpl House, Singapore 24...
# 9     333 Orchard Rd, #05-03 Hilton, Singapore 238867
# 10  9 Scotts Rd, #02-10 Pacific Plaza, Singapore 2...
# 11              425 River Valley Rd, Singapore 248324
# 12                   67 Killiney Rd, Singapore 239525
# 13  541 Orchard Rd, #01-01 Liat Towers, Singapore ...
# 14  2 Orchard Turn, #04-09/10 ION Orchard, Singapo...
# 15   333A Orchard Rd, #03 - 01 / 02, Singapore 238897
# 16              429 River Valley Rd, Singapore 248328
# 17  181 Orchard Road, Central, #04-01 Orchard, Sin...
# 18  190 Keng Lee Rd, #01-02 Chui Huay Lim Club, Si...
# 19  30 Bideford Rd, Level 1 COMO Orchard, Singapor...
# 20      2 Orchard Turn, #03 - 17/18, Singapore 238801
# 21  391A Orchard Rd, #05-34/35 Ngee Ann City, Sing...
# 22  320 Orchard Rd, #01-04 Singapore Marriott Tang...
# 23            313 Orchard Rd, B2-03, Singapore 238895
# 24  150 Orchard Rd, #01-49 Orchard Plaza, Singapor...
# 25                5 Koek Rd, #01-11, Singapore 228796
# 26  160 Orchard Rd, #02-03/04/05 Taste Orchard, Si...
# 27  583 Orchard Road, Forum The Shopping Mall, #01...
# 28  176 Orchard Road #01-33E The Centrepoint (Gast...
# 29  290 Orchard Rd, #05 - 04 / 05, Orchard Paragon...
# 30  333A Orchard Rd, #04-16 Mandarin Gallery, Sing...
# 31  111 Somerset Rd, #01-03/31/32 TripleOne Somers...
# 32  5 Koek Rd, #06-03 Cuppage Plaza, Singapore 228796
# 33  442 Orchard Rd, #01-08 Claymore Connect, Singa...
# 34          391 Orchard Rd, #04-18A, Singapore 238872
# 35  583 Orchard Rd, #01-28 Forum The Shopping Mall...
# 36                     22 Scotts Rd, Singapore 228221
# 37  290 Orchard Rd, #B1-01/02 Paragon Shopping Cen...
# 38   〒238841, Orchard Rd, 150号, Orchard Plaza, #03-55
#
#                                         googleMapsUrl  rating  ratingCount  \
# 0   https://maps.google.com/?cid=15313617145150253...     4.2        14394
# 1   https://maps.google.com/?cid=84417236615171968...     4.3         5873
# 2   https://maps.google.com/?cid=12654608137996577...     4.2         4002
# 3   https://maps.google.com/?cid=11189121388844722...     4.4         3386
# 4   https://maps.google.com/?cid=16152658315576182...     4.5         1770
# 5   https://maps.google.com/?cid=93120821624277402...     4.2         3830
# 6   https://maps.google.com/?cid=61167706209362305...     4.1         1280
# 7   https://maps.google.com/?cid=10087172446172084...     4.7         3538
# 8   https://maps.google.com/?cid=62668167263710306...     4.2         2800
# 9   https://maps.google.com/?cid=16905814961972302...     4.1         1477
# 10  https://maps.google.com/?cid=14514846216466486...     4.7         2695
# 11  https://maps.google.com/?cid=20292785496778386...     4.1         1446
# 12  https://maps.google.com/?cid=16970612318666188...     4.2         1772
# 13  https://maps.google.com/?cid=70456500043277659...     4.2         1347
# 14  https://maps.google.com/?cid=16020951657685427...     4.8         8782
# 15  https://maps.google.com/?cid=97176202857574091...     4.2         2051
# 16  https://maps.google.com/?cid=17014094132631005...     4.0         1530
# 17  https://maps.google.com/?cid=15828406587932105...     4.1         1859
# 18  https://maps.google.com/?cid=14779042864041968...     4.4         2553
# 19  https://maps.google.com/?cid=20629447700808706...     3.8         1017
# 20  https://maps.google.com/?cid=62569943895418659...     4.6         1546
# 21  https://maps.google.com/?cid=15252442297358635...     4.3         1523
# 22  https://maps.google.com/?cid=18428972005900218...     4.6          150
# 23  https://maps.google.com/?cid=71120452561772202...     4.8         1753
# 24  https://maps.google.com/?cid=73920030477943184...     4.9          102
# 25  https://maps.google.com/?cid=13679259889335354...     4.7          353
# 26  https://maps.google.com/?cid=58080753295329966...     4.0          205
# 27  https://maps.google.com/?cid=15364072581765247...     4.2         1146
# 28  https://maps.google.com/?cid=17929599182734137...     4.8         2021
# 29  https://maps.google.com/?cid=17846158831694482...     4.3         1074
# 30  https://maps.google.com/?cid=17061929669379417...     4.7          149
# 31  https://maps.google.com/?cid=15243602686433501...     4.8          298
# 32  https://maps.google.com/?cid=18984715291103478...     4.9          105
# 33  https://maps.google.com/?cid=16478305803852866...     4.5          189
# 34  https://maps.google.com/?cid=93312957399848356...     4.7           58
# 35  https://maps.google.com/?cid=14203804028504227...     4.6          544
# 36  https://maps.google.com/?cid=30480788390438208...     4.6          647
# 37  https://maps.google.com/?cid=33881356860373960...     3.8          438
# 38  https://maps.google.com/?cid=42457960109634417...     4.6          120
#
#                     priceLevel           primaryType  \
# 0                         None            food_court
# 1                         None                 hotel
# 2                         None                 hotel
# 3                         None                 hotel
# 4         PRICE_LEVEL_MODERATE            restaurant
# 5      PRICE_LEVEL_INEXPENSIVE            restaurant
# 6         PRICE_LEVEL_MODERATE            restaurant
# 7         PRICE_LEVEL_MODERATE     french_restaurant
# 8        PRICE_LEVEL_EXPENSIVE   american_restaurant
# 9        PRICE_LEVEL_EXPENSIVE            restaurant
# 10                        None            restaurant
# 11        PRICE_LEVEL_MODERATE    chinese_restaurant
# 12     PRICE_LEVEL_INEXPENSIVE     point_of_interest
# 13                        None  hamburger_restaurant
# 14  PRICE_LEVEL_VERY_EXPENSIVE    seafood_restaurant
# 15       PRICE_LEVEL_EXPENSIVE            restaurant
# 16        PRICE_LEVEL_MODERATE            restaurant
# 17        PRICE_LEVEL_MODERATE      asian_restaurant
# 18       PRICE_LEVEL_EXPENSIVE    chinese_restaurant
# 19                        None            restaurant
# 20                        None            restaurant
# 21        PRICE_LEVEL_MODERATE      sushi_restaurant
# 22                        None   japanese_restaurant
# 23        PRICE_LEVEL_MODERATE      sushi_restaurant
# 24                        None   japanese_restaurant
# 25                        None   japanese_restaurant
# 26                        None      sushi_restaurant
# 27                        None   japanese_restaurant
# 28        PRICE_LEVEL_MODERATE   japanese_restaurant
# 29        PRICE_LEVEL_MODERATE   japanese_restaurant
# 30                        None      sushi_restaurant
# 31                        None   japanese_restaurant
# 32                        None   japanese_restaurant
# 33                        None   japanese_restaurant
# 34                        None   japanese_restaurant
# 35                        None   japanese_restaurant
# 36  PRICE_LEVEL_VERY_EXPENSIVE      sushi_restaurant
# 37                        None      sushi_restaurant
# 38                        None      sushi_restaurant
#
#                                                 types
# 0   food_court,restaurant,point_of_interest,food,e...
# 1   hotel,lodging,restaurant,point_of_interest,foo...
# 2   hotel,lodging,wedding_venue,event_venue,restau...
# 3   hotel,buffet_restaurant,lodging,restaurant,poi...
# 4     restaurant,point_of_interest,food,establishment
# 5     restaurant,point_of_interest,food,establishment
# 6     restaurant,point_of_interest,food,establishment
# 7   french_restaurant,restaurant,point_of_interest...
# 8   american_restaurant,bar,event_venue,clothing_s...
# 9   asian_restaurant,restaurant,point_of_interest,...
# 10  restaurant,chinese_restaurant,buffet_restauran...
# 11  chinese_restaurant,restaurant,point_of_interes...
# 12  point_of_interest,breakfast_restaurant,coffee_...
# 13  hamburger_restaurant,american_restaurant,resta...
# 14  seafood_restaurant,restaurant,point_of_interes...
# 15  restaurant,breakfast_restaurant,point_of_inter...
# 16  breakfast_restaurant,coffee_shop,cafe,indian_r...
# 17  sushi_restaurant,wine_bar,asian_restaurant,bar...
# 18  chinese_restaurant,restaurant,point_of_interes...
# 19  restaurant,dessert_shop,confectionery,bakery,f...
# 20  restaurant,japanese_restaurant,food,point_of_i...
# 21  sushi_restaurant,japanese_restaurant,restauran...
# 22  japanese_restaurant,sushi_restaurant,restauran...
# 23  sushi_restaurant,japanese_restaurant,restauran...
# 24  japanese_restaurant,sushi_restaurant,seafood_r...
# 25  japanese_restaurant,restaurant,food,point_of_i...
# 26  sushi_restaurant,asian_restaurant,japanese_res...
# 27  japanese_restaurant,restaurant,food,point_of_i...
# 28  japanese_restaurant,restaurant,food,point_of_i...
# 29  japanese_restaurant,restaurant,food,point_of_i...
# 30  sushi_restaurant,fine_dining_restaurant,japane...
# 31  japanese_restaurant,restaurant,food,point_of_i...
# 32  japanese_restaurant,restaurant,food,point_of_i...
# 33  japanese_restaurant,restaurant,food,point_of_i...
# 34  japanese_restaurant,fine_dining_restaurant,res...
# 35  japanese_restaurant,bar_and_grill,bar,restaura...
# 36  sushi_restaurant,japanese_restaurant,restauran...
# 37  sushi_restaurant,japanese_restaurant,restauran...
# 38  sushi_restaurant,japanese_restaurant,restauran...
